# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, RepeatVector, TimeDistributed, Dense, MultiHeadAttention, Layer
from numpy.fft import fft
from scipy.stats import skew, kurtosis 
#from tensorflow_addons.layers import MultiHeadAttention
import matplotlib.pyplot as plt
import os
import struct
import glob
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report, accuracy_score
import time
totalMagnitude = 0
totalnumberofsamples = 0
def load_data(filepath):
    _, file_extension = os.path.splitext(filepath)
    
    if file_extension == '.csv':
        df = pd.read_csv(filepath)
        samples = df['your_column_name'].values
    elif file_extension == '.dat':
        #Looks like DAT is binary encoded added a b in r as rb
        with open(filepath, 'rb') as f:
            samples = f.readlines()
        samples = np.array([sample.strip() for sample in samples])
    else:
        raise ValueError(f"Unsupported file format: {file_extension}")
    
    return samples

def count_lines(filepath):
    with open(filepath, 'rb') as f:
        return sum(1 for _ in f)

class DataGenerator:        
    def __init__(self, filepath, batch_size, sequence_length, max_samples=None, for_training=True):
        self.filepath = filepath
        self.batch_size = batch_size
        self.sequence_length = sequence_length
        self.max_samples = max_samples
        self.for_training = for_training
        self.samples = []
        self.binary_file = open(self.filepath, 'rb')  # Initialize the binary_file here
        self.reset()

    def reset(self):
        self.total_samples_processed = 0
        _, self.file_extension = os.path.splitext(self.filepath)
        print(f"File extension detected: {self.file_extension}")  # Add this line


    def __iter__(self):
        self.binary_file.seek(0)  # reset file pointer
        self.samples = []
        return self
    
    def close(self):
        if not self.binary_file.closed:
            self.binary_file.close()

    def process_data(self, samples):
        real_parts = []
        imag_parts = []
        for sample in samples:
            try:
                cnum = complex(sample.replace('j', 'j'))
                real_parts.append(np.real(cnum))
                imag_parts.append(np.imag(cnum))
            except ValueError:
                continue

        real_parts = (real_parts - np.mean(real_parts)) / np.std(real_parts)
        imag_parts = (imag_parts - np.mean(imag_parts)) / np.std(imag_parts)

        X = [list(zip(real_parts[i:i+self.sequence_length], imag_parts[i:i+self.sequence_length])) for i in range(len(real_parts) - self.sequence_length)]
        return np.array(X)
    def process_data2(self, samples):
        # Convert samples list to a NumPy array and check the total number of samples
        samples_array = np.array(samples, dtype=np.complex64)
        total_samples = samples_array.size

        # Ensure that the total number of samples matches self.batch_size * self.sequence_length
        if total_samples != self.batch_size * self.sequence_length:
            # Handle this scenario: you might want to raise an error or handle it in some way
            raise ValueError("Total number of samples does not match batch_size * sequence_length")

        # Check for invalid values in samples_array before processing
        if np.isnan(samples_array).any() or np.isinf(samples_array).any():
            print(f"Invalid values found in samples_array: {samples_array}")
        # Reshape the samples array
        samples_array = samples_array.reshape(self.batch_size, self.sequence_length)
        #print('samples_array.shape:', samples_array.shape)

        # Apply FFT to convert time-domain signals into frequency domain
        samples_fft = fft(samples_array)
        #print('samples_fft.shape:', samples_fft.shape)

        # Extract real and imaginary parts
        real_parts = np.real(samples_fft)
        imag_parts = np.imag(samples_fft)

#         # Normalize the real and imaginary parts
#         real_parts = (real_parts - np.mean(real_parts, axis=1, keepdims=True)) / np.std(real_parts, axis=1, keepdims=True)
#         imag_parts = (imag_parts - np.mean(imag_parts, axis=1, keepdims=True)) / np.std(imag_parts, axis=1, keepdims=True)
        
        # Normalize the real and imaginary parts
        epsilon = 1e-10
        real_parts_mean = np.mean(real_parts, axis=1, keepdims=True)
        real_parts_std = np.std(real_parts, axis=1, keepdims=True)
        real_parts_std[real_parts_std == 0] = epsilon  # Avoid division by zero
        real_parts = (real_parts - real_parts_mean) / real_parts_std

        imag_parts_mean = np.mean(imag_parts, axis=1, keepdims=True)
        imag_parts_std = np.std(imag_parts, axis=1, keepdims=True)
        imag_parts_std[imag_parts_std == 0] = epsilon  # Avoid division by zero
        imag_parts = (imag_parts - imag_parts_mean) / imag_parts_std

        # Extract statistical features from the real and imaginary parts
        features = np.column_stack((
            np.mean(real_parts, axis=1),
            np.std(real_parts, axis=1),
            skew(real_parts, axis=1),
            kurtosis(real_parts, axis=1),
            np.mean(imag_parts, axis=1),
            np.std(imag_parts, axis=1),
            skew(imag_parts, axis=1),
            kurtosis(imag_parts, axis=1)
        ))

        # Reshape features to match the input shape of the model
        X = features.reshape(-1, self.sequence_length, features.shape[1])
        return X

    def __next__(self):
        chunksize = self.batch_size * self.sequence_length
        global totalMagnitude  # Access the global variable
        global totalnumberofsamples  # Access the global variable
        
        #if self.file_extension == '.dat':        
        samples = []
        while True:
            binary_data = self.binary_file.read(8)
            if not binary_data:
                break  # End of file
            decoded_data = struct.unpack('ff', binary_data)
            
            # Skip samples that are exactly zero (0 + 0j)
            if decoded_data[0] == 0 and decoded_data[1] == 0:
                continue

            # Convert the binary data to a complex number string
            decoded_line = f"{decoded_data[0]}+{decoded_data[1]}j\n" if decoded_data[1] >= 0 else f"{decoded_data[0]}{decoded_data[1]}j\n"
            samples.append(decoded_line)

            # Check if we have enough samples for a batch
            if len(samples) == chunksize:
                X_chunk = self.process_data2(samples)
                if self.for_training:
                    return X_chunk, X_chunk
                else:
                    return X_chunk
                # Clear samples for the next batch (optional, depends on your logic)
                samples = []

def plot_with_intrusions8(all_X_chunk_test, all_X_chunk_pred, all_intrusion_flags, sequence_length, save_path):
    for idx in range(0, len(all_X_chunk_test), sequence_length):
        sequence_idx = idx // sequence_length
        if all_intrusion_flags[sequence_idx]:
            plt.figure(figsize=(14, 6))
            time_steps = np.arange(idx * sequence_length, (idx + 1) * sequence_length)

            real_part_test = all_X_chunk_test[idx, :, 0].reshape(-1)
            imag_part_test = all_X_chunk_test[idx, :, 1].reshape(-1)
            real_part_pred = all_X_chunk_pred[idx, :, 0].reshape(-1)
            imag_part_pred = all_X_chunk_pred[idx, :, 1].reshape(-1)

            plt.plot(time_steps, real_part_test, 'b-', label='Original Real', linewidth=2)
            plt.plot(time_steps, real_part_pred, 'r--', label='Reconstructed Real', linewidth=2)
            plt.plot(time_steps, imag_part_test, 'g-', label='Original Imag', linewidth=2)
            plt.plot(time_steps, imag_part_pred, 'y--', label='Reconstructed Imag', linewidth=2)
            
            # Define where the fill should be applied (assuming the entire range for this example)
            where_fill = np.full_like(time_steps, True, dtype=bool)  # Fill the entire range
            plt.fill_between(time_steps, -3, 3, where=where_fill, color=(1, 0.5, 0.5), alpha=0.3, label='Intrusion Detected')

            #plt.fill_between(time_steps, -3, 3, where=True, color=(1, 0.5, 0.5), alpha=0.3, label='Intrusion Detected')
            
            # Enhancing font size and making bold
            plt.title(f'Original vs Reconstructed with Intrusion (Sequence {sequence_idx})', fontsize=18, fontweight='bold')
            plt.xlabel('Sample Index', fontsize=16, fontweight='bold')
            plt.ylabel('IQ Sample', fontsize=16, fontweight='bold')
            plt.legend(loc='lower right', fontsize=15)

            # Enhancing xtick and ytick labels
            for label in (plt.gca().get_xticklabels() + plt.gca().get_yticklabels()):
                label.set_fontsize(13)
                label.set_fontweight('bold')

            plt.tight_layout()

            filename = os.path.join(save_path, f'intrusion_sequence_{sequence_idx}.png')
            plt.savefig(filename)
            plt.close()

sequence_length = 10
#-------------------------------SelfAttention-RNN---------------------------------------
class SelfAttentionLayer(Layer):
    def __init__(self, num_heads, key_dim):
        super(SelfAttentionLayer, self).__init__()
        self.multi_head_attention = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)
    def call(self, inputs):
        return self.multi_head_attention(inputs, inputs, inputs)

model = Sequential()
# Input LSTM layer
model.add(LSTM(100, activation='relu', input_shape=(sequence_length, 8), return_sequences=True))  # Adjusted input_shape
# Self-attention layer
model.add(SelfAttentionLayer(num_heads=8, key_dim=100))
# Rest of the model remains the same
model.add(LSTM(50, activation='relu', return_sequences=False))
model.add(RepeatVector(sequence_length))
model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(LSTM(100, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(8)))  # Adjusted units in Dense layer

model.summary()
model.compile(optimizer='adam', loss='mse')
batch_size = 100

max_train_samples = 4000000  # I limit the train or can put None for whole data
train_steps = (max_train_samples) // (batch_size * sequence_length)
max_samples = 4000000  # Maximum samples to read (or None to read all)
max_test_samples = 4000000

# Example file patterns

num_pure_samples = count_lines('/home/mreza/5G accelerator/IQ_samples/data collected/5G_DL_IQ_no_jamming_0924.dat')
print('num_pure_samples:', num_pure_samples)
pure_file_pattern = '/home/mreza/5G accelerator/ID_MEC/data generator/pure_data/pure_iq_samples_*.csv'
mixed_file_pattern = '/home/mreza/5G accelerator/ID_MEC/data generator/mixed_data/mixed_iq_samples_*.csv'
pure_file_new = '/home/mreza/5G accelerator/ID_MEC/data generator/New Data-Collection/rx_IQ_pure'
mixed_file_new = '/home/mreza/5G accelerator/ID_MEC/data generator/New Data-Collection/rx_IQ_MIX'
pure_file_old = '/home/mreza/5G accelerator/IQ_samples/data collected/5G_DL_IQ_no_jamming_0924.dat'
mixed_file_old = '/home/mreza/5G accelerator/IQ_samples/data collected/5G_DL_IQ_with_periodic_jamming_0928_02.dat'
# train_gen_instance = CSVDataGenerator(pure_file_pattern, batch_size, sequence_length, 
#                                       max_samples, for_training=True)
# combined_gen_instance = CSVDataGenerator(mixed_file_pattern, batch_size, sequence_length, 
#                                          max_test_samples, for_training=False)

train_gen_instance = DataGenerator(pure_file_new,batch_size=batch_size, sequence_length=sequence_length, 
                                   max_samples=max_train_samples, for_training=True)
combined_gen_instance = DataGenerator(mixed_file_new,batch_size=batch_size, sequence_length=sequence_length, 
                                      for_training=False)

num_epochs = 20  # You can adjust the number of epochs as needed
steps_per_epoch = train_steps  # Assuming one epoch processes all the data
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")
    train_gen_instance.reset()  # Reset the generator at the beginning of each epoch
    for step in range(steps_per_epoch):
        try:
            X_chunk, Y_chunk = next(train_gen_instance)
        except StopIteration:
            train_gen_instance.reset()  # Reset the generator when it runs out of data
            X_chunk, Y_chunk = next(train_gen_instance)

        loss = model.train_on_batch(X_chunk, Y_chunk)
        #print(f"Step {step + 1}/{steps_per_epoch}", end='\r')
        if step % 200 == 0:
            print(f"Step {step + 1}/{train_steps}, Loss: {loss}")
    print()
    
num_predictions = 2000  # or any other large number
print(f"Number of predictions to be performed: {num_predictions}")


reconstruction_errors = []
all_X_chunk_test = []
all_X_chunk_pred = []
all_intrusion_flags = []
prediction_times = []
try:
    for _ in range(num_predictions):
        print('prediction number:', _)
        start_time = time.time()
        X_chunk_test = next(combined_gen_instance)
        X_chunk_pred = model.predict(X_chunk_test)
        prediction_times.append(time.time() - start_time)
        chunk_errors = np.mean(np.square(X_chunk_test - X_chunk_pred), axis=1)
        reconstruction_errors.extend(chunk_errors)        
        all_X_chunk_test.append(X_chunk_test)
        all_X_chunk_pred.append(X_chunk_pred)
except StopIteration:
    print("All samples processed.")

reconstruction_error = np.array(reconstruction_errors)
print('reconstruction_error.shape:', reconstruction_error.shape)
print('Number of NaNs in reconstruction_error:', np.isnan(reconstruction_error).sum())

#---------------------------------------111-----------------------------------
#max_error_per_sequence = reconstruction_error.reshape(-1, 8).max(axis=1)  # Shape (num_predictions * batch_size * sequence_length,)
max_error_per_sequence = reconstruction_error.max(axis=1) # Max error for each sequence
print('max_error_per_sequence:', max_error_per_sequence)

#error_per_sequence = max_error_per_sequence.reshape(-1, sequence_length).mean(axis=1)  # Shape (num_predictions * batch_size,)
# Determine the threshold for intrusion
#threshold1 = np.percentile(error_per_sequence, 99.6)
threshold1 = np.percentile(max_error_per_sequence, 99.6)
print('threshold1:', threshold1)
threshold2 = np.percentile(reconstruction_error, 95)
print('threshold percentile:', threshold2)

#is_intrusion_detected = error_per_sequence > threshold1  # Boolean array for sequences, shape (num_predictions * batch_size,)
is_intrusion_detected = max_error_per_sequence > threshold1  # Boolean array for sequences
print('len(is_intrusion_detected):', len(is_intrusion_detected))
print('is_intrusion_detected.shape:', is_intrusion_detected.shape)
#num_total_sequences = num_predictions * batch_size - num_predictions
num_total_sequences = len(max_error_per_sequence)
print('num_total_sequences:', num_total_sequences)
#---------------------------------------finish 111-----------------------------------
#flat_error_per_sequence = error_per_sequence.flatten()
flat_error_per_sequence = max_error_per_sequence.flatten()
# Determine if intrusion detected for each sequence
for error in flat_error_per_sequence:
    all_intrusion_flags.append(error > threshold1)    
all_X_chunk_test = np.concatenate(all_X_chunk_test, axis=0)
all_X_chunk_pred = np.concatenate(all_X_chunk_pred, axis=0)
#save_path = 'C:\\Users\\Mohammadreza\\Desktop\\My Class\\Proj-DC\\My Works\\My Papers\\intrusion\\data generator\\intrusion_detected'
#plot_with_intrusions8(all_X_chunk_test, all_X_chunk_pred, all_intrusion_flags, sequence_length, save_path)
#---------------------------------------------------------------------------
#jamming_detected = reconstruction_error > threshold2
jamming_detected = reconstruction_error > threshold1
train_gen_instance.close()
combined_gen_instance.close()
#Table to get insight
flattened_jamming_detected = jamming_detected.flatten()
real_part_detected = jamming_detected[:, 0]
imag_part_detected = jamming_detected[:, 1]

real_true_count = np.sum(real_part_detected)
real_false_count = len(real_part_detected) - real_true_count

imag_true_count = np.sum(imag_part_detected)
imag_false_count = len(imag_part_detected) - imag_true_count
# Overall
overall_true_count = np.sum(flattened_jamming_detected)
overall_false_count = len(flattened_jamming_detected) - overall_true_count
# Table-DataFrame
df = pd.DataFrame({
    'Part': ['Real', 'Imaginary', 'Overall'],
    'True Count': [real_true_count, imag_true_count, overall_true_count],
    'False Count': [real_false_count, imag_false_count, overall_false_count]
})
print(df)
num_jamming_detected = np.sum(jamming_detected)
print(f"Number of jamming sequences detected: {num_jamming_detected} out of {len(flattened_jamming_detected)} sequences")
# Out:
# 2024-02-29 12:54:50.901997: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-29 12:54:50.903041: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-29 12:54:50.927800: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-29 12:54:50.928387: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-29 12:54:51.548156: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 100)           43600
#
#  self_attention_layer (Self  (None, 10, 100)           322500
#  AttentionLayer)
#
#  lstm_1 (LSTM)               (None, 50)                30200
#
#  repeat_vector (RepeatVecto  (None, 10, 50)            0
#  r)
#
#  lstm_2 (LSTM)               (None, 10, 50)            20200
#
#  lstm_3 (LSTM)               (None, 10, 100)           60400
#
#  time_distributed (TimeDist  (None, 10, 8)             808
#  ributed)
#
# =================================================================
# Total params: 477708 (1.82 MB)
# Trainable params: 477708 (1.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# num_pure_samples: 5272809
# File extension detected:
# File extension detected:
# Epoch 1/20
# File extension detected:
# Step 1/4000, Loss: 1.5326913595199585
# Step 201/4000, Loss: 0.2673383057117462
# Step 401/4000, Loss: 0.2638188600540161
# Step 601/4000, Loss: 0.27989688515663147
# Step 801/4000, Loss: 1.7647120952606201
# Step 1001/4000, Loss: 0.3143206834793091
# Step 1201/4000, Loss: 0.22895541787147522
# Step 1401/4000, Loss: 0.18536825478076935
# Step 1601/4000, Loss: 0.2464400827884674
# Step 1801/4000, Loss: 1.4480785131454468
# Step 2001/4000, Loss: 0.3508809804916382
# Step 2201/4000, Loss: 1.7576450109481812
# Step 2401/4000, Loss: 0.27843737602233887
# Step 2601/4000, Loss: 1.4384137392044067
# Step 2801/4000, Loss: 2.0177500247955322
# Step 3001/4000, Loss: 0.27935105562210083
# Step 3201/4000, Loss: 1.5029613971710205
# Step 3401/4000, Loss: 1.0001603364944458
# Step 3601/4000, Loss: 1.701341986656189
# Step 3801/4000, Loss: 0.2457922399044037
#
# Epoch 2/20
# File extension detected:
# Step 1/4000, Loss: 1.6290934085845947
# Step 201/4000, Loss: 1.5549566745758057
# Step 401/4000, Loss: 0.1943357288837433
# Step 601/4000, Loss: 0.31203484535217285
# Step 801/4000, Loss: 0.22133450210094452
# Step 1001/4000, Loss: 0.30018365383148193
# Step 1201/4000, Loss: 0.22280624508857727
# Step 1401/4000, Loss: 0.2641674280166626
# Step 1601/4000, Loss: 1.2993985414505005
# Step 1801/4000, Loss: 0.8955451846122742
# Step 2001/4000, Loss: 0.25623026490211487
# Step 2201/4000, Loss: 0.28960028290748596
# Step 2401/4000, Loss: 1.299257516860962
# Step 2601/4000, Loss: 0.47529834508895874
# Step 2801/4000, Loss: 0.24929657578468323
# Step 3001/4000, Loss: 0.2275611162185669
# Step 3201/4000, Loss: 0.753236711025238
# Step 3401/4000, Loss: 0.24748924374580383
# Step 3601/4000, Loss: 0.23112241923809052
# Step 3801/4000, Loss: 0.2875318229198456
#
# Epoch 3/20
# File extension detected:
# Step 1/4000, Loss: 0.24312801659107208
# Step 201/4000, Loss: 0.3065583407878876
# Step 401/4000, Loss: 0.24947002530097961
# Step 601/4000, Loss: 0.18173591792583466
# Step 801/4000, Loss: 0.16570907831192017
# Step 1001/4000, Loss: 0.28896254301071167
# Step 1201/4000, Loss: 0.24725505709648132
# Step 1401/4000, Loss: 1.0916873216629028
# Step 1601/4000, Loss: 0.27047574520111084
# Step 1801/4000, Loss: 0.45167532563209534
# Step 2001/4000, Loss: 0.22104854881763458
# Step 2201/4000, Loss: 0.9422647356987
# Step 2401/4000, Loss: 0.24608318507671356
# Step 2601/4000, Loss: 0.1864139586687088
# Step 2801/4000, Loss: 0.23119156062602997
# Step 3001/4000, Loss: 0.709460437297821
# Step 3201/4000, Loss: 0.2594083845615387
# Step 3401/4000, Loss: 0.17141371965408325
# Step 3601/4000, Loss: 0.22808805108070374
# Step 3801/4000, Loss: 0.18916867673397064
#
# Epoch 4/20
# File extension detected:
# Step 1/4000, Loss: 0.19790388643741608
# Step 201/4000, Loss: 0.24063065648078918
# Step 401/4000, Loss: 0.19041402637958527
# Step 601/4000, Loss: 0.17557193338871002
# Step 801/4000, Loss: 0.1952352076768875
# Step 1001/4000, Loss: 0.20307424664497375
# Step 1201/4000, Loss: 0.9289414286613464
# Step 1401/4000, Loss: 0.23988232016563416
# Step 1601/4000, Loss: 0.19455215334892273
# Step 1801/4000, Loss: 0.23052425682544708
# Step 2001/4000, Loss: 0.907127857208252
# Step 2201/4000, Loss: 0.22577795386314392
# Step 2401/4000, Loss: 0.22761254012584686
# Step 2601/4000, Loss: 0.18666698038578033
# Step 2801/4000, Loss: 0.8052970767021179
# Step 3001/4000, Loss: 0.1998022198677063
# Step 3201/4000, Loss: 0.20719723403453827
# Step 3401/4000, Loss: 0.15153880417346954
# Step 3601/4000, Loss: 0.2021068036556244
# Step 3801/4000, Loss: 0.15222589671611786
#
# Epoch 5/20
# File extension detected:
# Step 1/4000, Loss: 0.19442342221736908
# Step 201/4000, Loss: 0.16878944635391235
# Step 401/4000, Loss: 0.904407799243927
# Step 601/4000, Loss: 0.20990392565727234
# Step 801/4000, Loss: 0.1724170446395874
# Step 1001/4000, Loss: 0.7410558462142944
# Step 1201/4000, Loss: 0.21395055949687958
# Step 1401/4000, Loss: 0.16698123514652252
# Step 1601/4000, Loss: 0.1608634889125824
# Step 1801/4000, Loss: 0.6976242065429688
# Step 2001/4000, Loss: 0.8882306814193726
# Step 2201/4000, Loss: 0.2158527821302414
# Step 2401/4000, Loss: 0.15430927276611328
# Step 2601/4000, Loss: 0.6145530343055725
# Step 2801/4000, Loss: 0.1504041701555252
# Step 3001/4000, Loss: 0.17703472077846527
# Step 3201/4000, Loss: 0.19074344635009766
# Step 3401/4000, Loss: 0.24350178241729736
# Step 3601/4000, Loss: 0.22822709381580353
# Step 3801/4000, Loss: 0.22773750126361847
#
# Epoch 6/20
# File extension detected:
# Step 1/4000, Loss: 0.13647140562534332
# Step 201/4000, Loss: 0.22747096419334412
# Step 401/4000, Loss: 0.17843370139598846
# Step 601/4000, Loss: 0.12045346200466156
# Step 801/4000, Loss: 0.8077942132949829
# Step 1001/4000, Loss: 0.1757233589887619
# Step 1201/4000, Loss: 0.1488581895828247
# Step 1401/4000, Loss: 0.17874453961849213
# Step 1601/4000, Loss: 0.6803953647613525
# Step 1801/4000, Loss: 0.1527244597673416
# Step 2001/4000, Loss: 0.16649019718170166
# Step 2201/4000, Loss: 0.15467724204063416
# Step 2401/4000, Loss: 0.5592623353004456
# Step 2601/4000, Loss: 0.1531113088130951
# Step 2801/4000, Loss: 0.1400243639945984
# Step 3001/4000, Loss: 0.12645699083805084
# Step 3201/4000, Loss: 0.13677318394184113
# Step 3401/4000, Loss: 0.14581076800823212
# Step 3601/4000, Loss: 0.10800103843212128
# Step 3801/4000, Loss: 0.12819695472717285
#
# Epoch 7/20
# File extension detected:
# Step 1/4000, Loss: 0.15381862223148346
# Step 201/4000, Loss: 0.12397358566522598
# Step 401/4000, Loss: 0.14471420645713806
# Step 601/4000, Loss: 0.6004383563995361
# Step 801/4000, Loss: 0.16101008653640747
# Step 1001/4000, Loss: 0.16458271443843842
# Step 1201/4000, Loss: 0.13148194551467896
# Step 1401/4000, Loss: 0.6127228736877441
# Step 1601/4000, Loss: 0.2049913853406906
# Step 1801/4000, Loss: 0.16328653693199158
# Step 2001/4000, Loss: 0.13075168430805206
# Step 2201/4000, Loss: 0.48311203718185425
# Step 2401/4000, Loss: 0.13401277363300323
# Step 2601/4000, Loss: 0.1193072572350502
# Step 2801/4000, Loss: 0.11681444942951202
# Step 3001/4000, Loss: 0.12261305004358292
# Step 3201/4000, Loss: 0.1277441829442978
# Step 3401/4000, Loss: 0.1085326299071312
# Step 3601/4000, Loss: 0.10946010053157806
# Step 3801/4000, Loss: 0.14257796108722687
#
# Epoch 8/20
# File extension detected:
# Step 1/4000, Loss: 0.12330517917871475
# Step 201/4000, Loss: 0.09537631273269653
# Step 401/4000, Loss: 0.4014941155910492
# Step 601/4000, Loss: 0.2776658535003662
# Step 801/4000, Loss: 0.16674190759658813
# Step 1001/4000, Loss: 0.12659044563770294
# Step 1201/4000, Loss: 0.46089667081832886
# Step 1401/4000, Loss: 0.08596248924732208
# Step 1601/4000, Loss: 0.1310296207666397
# Step 1801/4000, Loss: 0.11455504596233368
# Step 2001/4000, Loss: 0.3446584939956665
# Step 2201/4000, Loss: 0.1304413378238678
# Step 2401/4000, Loss: 0.10531340539455414
# Step 2601/4000, Loss: 0.1419268101453781
# Step 2801/4000, Loss: 0.14384986460208893
# Step 3001/4000, Loss: 0.0934436097741127
# Step 3201/4000, Loss: 0.11594792455434799
# Step 3401/4000, Loss: 0.08881230652332306
# Step 3601/4000, Loss: 0.09866305440664291
# Step 3801/4000, Loss: 0.10324431955814362
#
# Epoch 9/20
# File extension detected:
# Step 1/4000, Loss: 0.09931312501430511
# Step 201/4000, Loss: 0.4150563180446625
# Step 401/4000, Loss: 0.11033596098423004
# Step 601/4000, Loss: 0.06447061151266098
# Step 801/4000, Loss: 0.09245521575212479
# Step 1001/4000, Loss: 0.30937328934669495
# Step 1201/4000, Loss: 0.10332278907299042
# Step 1401/4000, Loss: 0.08713752776384354
# Step 1601/4000, Loss: 0.09925103932619095
# Step 1801/4000, Loss: 0.3317473232746124
# Step 2001/4000, Loss: 0.07340878248214722
# Step 2201/4000, Loss: 0.09535424411296844
# Step 2401/4000, Loss: 0.0866619199514389
# Step 2601/4000, Loss: 0.392503023147583
# Step 2801/4000, Loss: 0.07031035423278809
# Step 3001/4000, Loss: 0.09818455576896667
# Step 3201/4000, Loss: 0.07734096795320511
# Step 3401/4000, Loss: 0.12153251469135284
# Step 3601/4000, Loss: 0.0792289599776268
# Step 3801/4000, Loss: 0.07406851649284363
#
# Epoch 10/20
# File extension detected:
# Step 1/4000, Loss: 0.23638573288917542
# Step 201/4000, Loss: 0.3079015612602234
# Step 401/4000, Loss: 0.09568330645561218
# Step 601/4000, Loss: 0.09585443139076233
# Step 801/4000, Loss: 0.26046961545944214
# Step 1001/4000, Loss: 0.08500807732343674
# Step 1201/4000, Loss: 0.07740268856287003
# Step 1401/4000, Loss: 0.09065330773591995
# Step 1601/4000, Loss: 0.33452004194259644
# Step 1801/4000, Loss: 0.4564822316169739
# Step 2001/4000, Loss: 0.09969544410705566
# Step 2201/4000, Loss: 0.0644029900431633
# Step 2401/4000, Loss: 0.08843009918928146
# Step 2601/4000, Loss: 0.1051003709435463
# Step 2801/4000, Loss: 0.3069148361682892
# Step 3001/4000, Loss: 0.0761735811829567
# Step 3201/4000, Loss: 0.097816102206707
# Step 3401/4000, Loss: 0.08861479163169861
# Step 3601/4000, Loss: 0.06785207986831665
# Step 3801/4000, Loss: 0.20457246899604797
#
# Epoch 11/20
# File extension detected:
# Step 1/4000, Loss: 0.08515375852584839
# Step 201/4000, Loss: 0.06052781268954277
# Step 401/4000, Loss: 0.07801869511604309
# Step 601/4000, Loss: 0.19841039180755615
# Step 801/4000, Loss: 0.06898728013038635
# Step 1001/4000, Loss: 0.10296335071325302
# Step 1201/4000, Loss: 0.07166626304388046
# Step 1401/4000, Loss: 0.19345282018184662
# Step 1601/4000, Loss: 0.08202614635229111
# Step 1801/4000, Loss: 0.06888163834810257
# Step 2001/4000, Loss: 0.06983327120542526
# Step 2201/4000, Loss: 0.10141463577747345
# Step 2401/4000, Loss: 0.06244529411196709
# Step 2601/4000, Loss: 0.08491586893796921
# Step 2801/4000, Loss: 0.06133188679814339
# Step 3001/4000, Loss: 0.06629453599452972
# Step 3201/4000, Loss: 0.05541260167956352
# Step 3401/4000, Loss: 0.05403938889503479
# Step 3601/4000, Loss: 0.17966054379940033
# Step 3801/4000, Loss: 0.07257261872291565
#
# Epoch 12/20
# File extension detected:
# Step 1/4000, Loss: 0.05576406046748161
# Step 201/4000, Loss: 0.050054632127285004
# Step 401/4000, Loss: 0.1936248242855072
# Step 601/4000, Loss: 0.05137399584054947
# Step 801/4000, Loss: 0.08761923015117645
# Step 1001/4000, Loss: 0.05279996991157532
# Step 1201/4000, Loss: 0.06932342797517776
# Step 1401/4000, Loss: 0.04366735368967056
# Step 1601/4000, Loss: 0.05342361330986023
# Step 1801/4000, Loss: 0.195918470621109
# Step 2001/4000, Loss: 0.07252930849790573
# Step 2201/4000, Loss: 0.05937368795275688
# Step 2401/4000, Loss: 0.05314645916223526
# Step 2601/4000, Loss: 0.09775665402412415
# Step 2801/4000, Loss: 0.1774442046880722
# Step 3001/4000, Loss: 0.0457332618534565
# Step 3201/4000, Loss: 0.04068709537386894
# Step 3401/4000, Loss: 0.2217109501361847
# Step 3601/4000, Loss: 0.052995048463344574
# Step 3801/4000, Loss: 0.05969281122088432
#
# Epoch 13/20
# File extension detected:
# Step 1/4000, Loss: 0.04531855508685112
# Step 201/4000, Loss: 0.05249311774969101
# Step 401/4000, Loss: 0.04995031654834747
# Step 601/4000, Loss: 0.04150944575667381
# Step 801/4000, Loss: 0.03986700251698494
# Step 1001/4000, Loss: 0.12183795869350433
# Step 1201/4000, Loss: 0.03613943234086037
# Step 1401/4000, Loss: 0.07064400613307953
# Step 1601/4000, Loss: 0.06601046770811081
# Step 1801/4000, Loss: 0.03590444475412369
# Step 2001/4000, Loss: 0.03560400754213333
# Step 2201/4000, Loss: 0.03346949443221092
# Step 2401/4000, Loss: 0.11392267048358917
# Step 2601/4000, Loss: 0.03574857488274574
# Step 2801/4000, Loss: 0.043594371527433395
# Step 3001/4000, Loss: 0.04102897644042969
# Step 3201/4000, Loss: 0.09710241109132767
# Step 3401/4000, Loss: 0.03402247652411461
# Step 3601/4000, Loss: 0.0441744290292263
# Step 3801/4000, Loss: 0.03141755610704422
#
# Epoch 14/20
# File extension detected:
# Step 1/4000, Loss: 0.06634727120399475
# Step 201/4000, Loss: 0.0411665253341198
# Step 401/4000, Loss: 0.026129061356186867
# Step 601/4000, Loss: 0.029999595135450363
# Step 801/4000, Loss: 0.08134915679693222
# Step 1001/4000, Loss: 0.0501188263297081
# Step 1201/4000, Loss: 0.02929636277258396
# Step 1401/4000, Loss: 0.0485675111413002
# Step 1601/4000, Loss: 0.037399519234895706
# Step 1801/4000, Loss: 0.04226448014378548
# Step 2001/4000, Loss: 0.03722881153225899
# Step 2201/4000, Loss: 0.090766042470932
# Step 2401/4000, Loss: 0.08449354022741318
# Step 2601/4000, Loss: 0.03297756239771843
# Step 2801/4000, Loss: 0.024705540388822556
# Step 3001/4000, Loss: 0.034210849553346634
# Step 3201/4000, Loss: 0.02995149791240692
# Step 3401/4000, Loss: 0.03695545345544815
# Step 3601/4000, Loss: 0.023288022726774216
# Step 3801/4000, Loss: 0.04917962849140167
#
# Epoch 15/20
# File extension detected:
# Step 1/4000, Loss: 0.04129264876246452
# Step 201/4000, Loss: 0.02735128626227379
# Step 401/4000, Loss: 0.02145697921514511
# Step 601/4000, Loss: 0.06292553246021271
# Step 801/4000, Loss: 0.023162120953202248
# Step 1001/4000, Loss: 0.03325050324201584
# Step 1201/4000, Loss: 0.027028625831007957
# Step 1401/4000, Loss: 0.054082781076431274
# Step 1601/4000, Loss: 0.029759163036942482
# Step 1801/4000, Loss: 0.02784305438399315
# Step 2001/4000, Loss: 0.015384328551590443
# Step 2201/4000, Loss: 0.06293100863695145
# Step 2401/4000, Loss: 0.03219547122716904
# Step 2601/4000, Loss: 0.02284153550863266
# Step 2801/4000, Loss: 0.018685299903154373
# Step 3001/4000, Loss: 0.0331767238676548
# Step 3201/4000, Loss: 0.026719555258750916
# Step 3401/4000, Loss: 0.025050971657037735
# Step 3601/4000, Loss: 0.051515646278858185
# Step 3801/4000, Loss: 0.02066870406270027
#
# Epoch 16/20
# File extension detected:
# Step 1/4000, Loss: 0.020561840385198593
# Step 201/4000, Loss: 0.02123982273042202
# Step 401/4000, Loss: 0.04900448024272919
# Step 601/4000, Loss: 0.023306457325816154
# Step 801/4000, Loss: 0.017595531418919563
# Step 1001/4000, Loss: 0.02432345412671566
# Step 1201/4000, Loss: 0.02006513625383377
# Step 1401/4000, Loss: 0.03182043135166168
# Step 1601/4000, Loss: 0.022709734737873077
# Step 1801/4000, Loss: 0.015698367729783058
# Step 2001/4000, Loss: 0.047121018171310425
# Step 2201/4000, Loss: 0.06130751222372055
# Step 2401/4000, Loss: 0.02090727724134922
# Step 2601/4000, Loss: 0.02097468078136444
# Step 2801/4000, Loss: 0.07031720876693726
# Step 3001/4000, Loss: 0.024377277120947838
# Step 3201/4000, Loss: 0.020197076722979546
# Step 3401/4000, Loss: 0.01995987631380558
# Step 3601/4000, Loss: 0.03177108243107796
# Step 3801/4000, Loss: 0.05018051713705063
#
# Epoch 17/20
# File extension detected:
# Step 1/4000, Loss: 0.021544359624385834
# Step 201/4000, Loss: 0.017748279497027397
# Step 401/4000, Loss: 0.01942877471446991
# Step 601/4000, Loss: 0.02934129908680916
# Step 801/4000, Loss: 0.021120965480804443
# Step 1001/4000, Loss: 0.018402276560664177
# Step 1201/4000, Loss: 0.03347029536962509
# Step 1401/4000, Loss: 0.018193408846855164
# Step 1601/4000, Loss: 0.014630688354372978
# Step 1801/4000, Loss: 0.031542446464300156
# Step 2001/4000, Loss: 0.016035476699471474
# Step 2201/4000, Loss: 0.0221147108823061
# Step 2401/4000, Loss: 0.018479613587260246
# Step 2601/4000, Loss: 0.04811014607548714
# Step 2801/4000, Loss: 0.023268617689609528
# Step 3001/4000, Loss: 0.01858319342136383
# Step 3201/4000, Loss: 0.022233588621020317
# Step 3401/4000, Loss: 0.0391661562025547
# Step 3601/4000, Loss: 0.02648814395070076
# Step 3801/4000, Loss: 0.023492291569709778
#
# Epoch 18/20
# File extension detected:
# Step 1/4000, Loss: 0.016566487029194832
# Step 201/4000, Loss: 0.03808404505252838
# Step 401/4000, Loss: 0.016402950510382652
# Step 601/4000, Loss: 0.02125409059226513
# Step 801/4000, Loss: 0.01217842660844326
# Step 1001/4000, Loss: 0.023820368573069572
# Step 1201/4000, Loss: 0.018220001831650734
# Step 1401/4000, Loss: 0.018288657069206238
# Step 1601/4000, Loss: 0.027975942939519882
# Step 1801/4000, Loss: 0.014674347825348377
# Step 2001/4000, Loss: 0.02013634704053402
# Step 2201/4000, Loss: 0.022137625142931938
# Step 2401/4000, Loss: 0.033504143357276917
# Step 2601/4000, Loss: 0.05070725083351135
# Step 2801/4000, Loss: 0.015658710151910782
# Step 3001/4000, Loss: 0.016783392056822777
# 2024-02-29 13:13:27.924556: W tensorflow/core/data/root_dataset.cc:286] Optimization loop failed: CANCELLED: Operation was cancelled
# Step 3201/4000, Loss: 0.038835521787405014
# Step 3401/4000, Loss: 0.01760970987379551
# Step 3601/4000, Loss: 0.023478062823414803
# Step 3801/4000, Loss: 0.016151314601302147
#
# Epoch 19/20
# File extension detected:
# Step 1/4000, Loss: 0.029549365863204002
# Step 201/4000, Loss: 0.015504321083426476
# Step 401/4000, Loss: 0.01916808821260929
# Step 601/4000, Loss: 0.017422331497073174
# Step 801/4000, Loss: 0.018851375207304955
# Step 1001/4000, Loss: 0.02009900100529194
# Step 1201/4000, Loss: 0.018146686255931854
# Step 1401/4000, Loss: 0.012406869791448116
# Step 1601/4000, Loss: 0.017243163660168648
# Step 1801/4000, Loss: 0.019266847521066666
# Step 2001/4000, Loss: 0.024644926190376282
# Step 2201/4000, Loss: 0.03046116605401039
# Step 2401/4000, Loss: 0.02587205171585083
# Step 2601/4000, Loss: 0.02024701051414013
# Step 2801/4000, Loss: 0.013942420482635498
# Step 3001/4000, Loss: 0.05868936702609062
# Step 3201/4000, Loss: 0.018345829099416733
# Step 3401/4000, Loss: 0.010857776738703251
# Step 3601/4000, Loss: 0.014107163064181805
# Step 3801/4000, Loss: 0.028928663581609726
#
# Epoch 20/20
# File extension detected:
# Step 1/4000, Loss: 0.014206519350409508
# Step 201/4000, Loss: 0.015663759782910347
# Step 401/4000, Loss: 0.014955294318497181
# Step 601/4000, Loss: 0.02960813045501709
# Step 801/4000, Loss: 0.01710536889731884
# Step 1001/4000, Loss: 0.010724489577114582
# Step 1201/4000, Loss: 0.0118980398401618
# Step 1401/4000, Loss: 0.0187704935669899
# Step 1601/4000, Loss: 0.017339369282126427
# Step 1801/4000, Loss: 0.013880787417292595
# Step 2001/4000, Loss: 0.048213545233011246
# Step 2201/4000, Loss: 0.019917741417884827
# Step 2401/4000, Loss: 0.013219033367931843
# Step 2601/4000, Loss: 0.013594985008239746
# Step 2801/4000, Loss: 0.02488083392381668
# Step 3001/4000, Loss: 0.015458038076758385
# Step 3201/4000, Loss: 0.041755612939596176
# Step 3401/4000, Loss: 0.015177428722381592
# Step 3601/4000, Loss: 0.03838706389069557
# Step 3801/4000, Loss: 0.018297085538506508
#
# Number of predictions to be performed: 2000
# prediction number: 0
# 1/1 [==============================] - 0s 337ms/step
# prediction number: 1
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 2
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 3
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 4
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 5
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 6
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 7
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 8
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 9
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 10
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 11
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 12
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 13
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 14
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 15
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 16
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 17
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 18
# 1/1 [==============================] - 0s 21ms/step
# prediction number: 19
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 20
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 21
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 22
# 1/1 [==============================] - 0s 21ms/step
# prediction number: 23
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 24
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 25
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 26
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 27
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 28
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 29
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 30
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 31
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 32
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 33
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 34
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 35
# 1/1 [==============================] - 0s 24ms/step
# prediction number: 36
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 37
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 38
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 39
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 40
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 41
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 42
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 43
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 44
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 45
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 46
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 47
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 48
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 49
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 50
# 1/1 [==============================] - 0s 24ms/step
# prediction number: 51
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 52
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 53
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 54
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 55
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 56
# 1/1 [==============================] - 0s 21ms/step
# prediction number: 57
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 58
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 59
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 60
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 61
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 62
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 63
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 64
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 65
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 66
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 67
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 68
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 69
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 70
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 71
# 1/1 [==============================] - 0s 29ms/step
# prediction number: 72
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 73
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 74
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 75
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 76
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 77
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 78
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 79
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 80
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 81
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 82
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 83
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 84
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 85
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 86
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 87
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 88
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 89
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 90
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 91
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 92
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 93
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 94
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 95
# 1/1 [==============================] - 0s 21ms/step
# prediction number: 96
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 97
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 98
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 99
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 100
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 101
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 102
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 103
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 104
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 105
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 106
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 107
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 108
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 109
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 110
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 111
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 112
# 1/1 [==============================] - 0s 30ms/step
# prediction number: 113
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 114
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 115
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 116
# 1/1 [==============================] - 0s 21ms/step
# prediction number: 117
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 118
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 119
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 120
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 121
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 122
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 123
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 124
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 125
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 126
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 127
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 128
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 129
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 130
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 131
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 132
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 133
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 134
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 135
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 136
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 137
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 138
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 139
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 140
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 141
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 142
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 143
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 144
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 145
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 146
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 147
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 148
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 149
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 150
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 151
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 152
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 153
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 154
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 155
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 156
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 157
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 158
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 159
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 160
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 161
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 162
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 163
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 164
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 165
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 166
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 167
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 168
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 169
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 170
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 171
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 172
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 173
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 174
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 175
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 176
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 177
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 178
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 179
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 180
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 181
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 182
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 183
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 184
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 185
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 186
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 187
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 188
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 189
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 190
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 191
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 192
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 193
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 194
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 195
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 196
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 197
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 198
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 199
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 200
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 201
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 202
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 203
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 204
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 205
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 206
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 207
# 1/1 [==============================] - 0s 29ms/step
# prediction number: 208
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 209
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 210
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 211
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 212
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 213
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 214
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 215
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 216
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 217
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 218
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 219
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 220
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 221
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 222
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 223
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 224
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 225
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 226
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 227
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 228
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 229
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 230
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 231
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 232
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 233
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 234
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 235
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 236
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 237
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 238
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 239
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 240
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 241
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 242
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 243
# 1/1 [==============================] - 0s 34ms/step
# prediction number: 244
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 245
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 246
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 247
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 248
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 249
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 250
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 251
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 252
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 253
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 254
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 255
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 256
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 257
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 258
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 259
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 260
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 261
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 262
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 263
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 264
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 265
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 266
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 267
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 268
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 269
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 270
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 271
# 1/1 [==============================] - 0s 25ms/step
# prediction number: 272
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 273
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 274
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 275
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 276
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 277
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 278
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 279
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 280
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 281
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 282
# 1/1 [==============================] - 0s 25ms/step
# prediction number: 283
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 284
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 285
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 286
# 1/1 [==============================] - 0s 21ms/step
# prediction number: 287
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 288
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 289
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 290
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 291
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 292
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 293
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 294
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 295
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 296
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 297
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 298
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 299
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 300
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 301
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 302
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 303
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 304
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 305
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 306
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 307
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 308
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 309
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 310
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 311
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 312
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 313
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 314
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 315
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 316
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 317
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 318
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 319
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 320
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 321
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 322
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 323
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 324
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 325
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 326
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 327
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 328
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 329
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 330
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 331
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 332
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 333
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 334
# 1/1 [==============================] - 0s 25ms/step
# prediction number: 335
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 336
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 337
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 338
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 339
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 340
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 341
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 342
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 343
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 344
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 345
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 346
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 347
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 348
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 349
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 350
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 351
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 352
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 353
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 354
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 355
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 356
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 357
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 358
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 359
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 360
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 361
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 362
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 363
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 364
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 365
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 366
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 367
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 368
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 369
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 370
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 371
# ...
# prediction number: 1797
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1798
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1799
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1800
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1801
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1802
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1803
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 1804
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1805
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 1806
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1807
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1808
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1809
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1810
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1811
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1812
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1813
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1814
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1815
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1816
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1817
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1818
# 1/1 [==============================] - 0s 30ms/step
# prediction number: 1819
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1820
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 1821
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 1822
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1823
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1824
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1825
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1826
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1827
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1828
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1829
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1830
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1831
# 1/1 [==============================] - 0s 22ms/step
# prediction number: 1832
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1833
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 1834
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1835
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 1836
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1837
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1838
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 1839
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1840
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1841
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1842
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 1843
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1844
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 1845
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1846
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 1847
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1848
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1849
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1850
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1851
# 1/1 [==============================] - 0s 25ms/step
# prediction number: 1852
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1853
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 1854
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1855
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1856
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1857
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1858
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1859
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1860
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1861
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1862
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1863
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1864
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1865
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1866
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1867
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1868
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 1869
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1870
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 1871
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1872
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1873
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1874
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1875
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1876
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1877
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1878
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1879
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1880
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1881
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1882
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1883
# 1/1 [==============================] - 0s 25ms/step
# prediction number: 1884
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1885
# 1/1 [==============================] - 0s 30ms/step
# prediction number: 1886
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1887
# 1/1 [==============================] - 0s 24ms/step
# prediction number: 1888
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1889
# 1/1 [==============================] - 0s 22ms/step
# prediction number: 1890
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1891
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1892
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1893
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1894
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1895
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1896
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1897
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1898
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1899
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1900
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1901
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1902
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1903
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1904
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 1905
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1906
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 1907
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1908
# 1/1 [==============================] - 0s 31ms/step
# prediction number: 1909
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1910
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1911
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1912
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1913
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1914
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1915
# 1/1 [==============================] - 0s 22ms/step
# prediction number: 1916
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1917
# 1/1 [==============================] - 0s 29ms/step
# prediction number: 1918
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1919
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1920
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1921
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1922
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 1923
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1924
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1925
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1926
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1927
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1928
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1929
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1930
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1931
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1932
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1933
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1934
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 1935
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1936
# 1/1 [==============================] - 0s 25ms/step
# prediction number: 1937
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1938
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 1939
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1940
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 1941
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1942
# 1/1 [==============================] - 0s 24ms/step
# prediction number: 1943
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1944
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 1945
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1946
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1947
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1948
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1949
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1950
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 1951
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 1952
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1953
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 1954
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1955
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 1956
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1957
# 1/1 [==============================] - 0s 26ms/step
# prediction number: 1958
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1959
# 1/1 [==============================] - 0s 23ms/step
# prediction number: 1960
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1961
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1962
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1963
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1964
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1965
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 1966
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1967
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1968
# 1/1 [==============================] - 0s 18ms/step
# prediction number: 1969
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1970
# 1/1 [==============================] - 0s 17ms/step
# prediction number: 1971
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1972
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 1973
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 1974
# 1/1 [==============================] - 0s 27ms/step
# prediction number: 1975
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1976
# 1/1 [==============================] - 0s 28ms/step
# prediction number: 1977
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1978
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1979
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1980
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1981
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1982
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1983
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1984
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1985
# 1/1 [==============================] - 0s 19ms/step
# prediction number: 1986
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1987
# 1/1 [==============================] - 0s 20ms/step
# prediction number: 1988
# 1/1 [==============================] - 0s 15ms/step
# prediction number: 1989
# 1/1 [==============================] - 0s 25ms/step
# prediction number: 1990
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1991
# 1/1 [==============================] - 0s 29ms/step
# prediction number: 1992
# 1/1 [==============================] - 0s 14ms/step
# prediction number: 1993
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1994
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1995
# 1/1 [==============================] - 0s 12ms/step
# prediction number: 1996
# 1/1 [==============================] - 0s 16ms/step
# prediction number: 1997
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1998
# 1/1 [==============================] - 0s 13ms/step
# prediction number: 1999
# 1/1 [==============================] - 0s 12ms/step
# reconstruction_error.shape: (20000, 8)
# Number of NaNs in reconstruction_error: 0
# max_error_per_sequence: [0.08939479 0.10670463 0.11859546 ... 0.03964626 0.04627608 0.0169388 ]
# threshold1: 0.34686116329867467
# threshold percentile: 0.10879778433898288
# len(is_intrusion_detected): 20000
# is_intrusion_detected.shape: (20000,)
# num_total_sequences: 20000
#         Part  True Count  False Count
# 0       Real           0        20000
# 1  Imaginary           0        20000
# 2    Overall          81       159919
# Number of jamming sequences detected: 81 out of 160000 sequences

# %%
# Flatten the reconstruction_error to 1D
reconstruction_error_flat = reconstruction_error.flatten()
# reconstruction error
plt.figure(figsize=(14, 6))
plt.plot(reconstruction_error_flat, label='Reconstruction Error')
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error with Threshold')
plt.xlabel('Sequence Number')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('1-Reconstruction Error with Threshold.png')
# plt.close()
plt.show()

# %%
# reconstruction error
reconstruction_error_real_parts = reconstruction_error[:, 0]
reconstruction_error_real_std = reconstruction_error[:, 1]
reconstruction_error_real_skew = reconstruction_error[:, 2]
reconstruction_error_real_kurtosis = reconstruction_error[:, 3]
reconstruction_error_imag_parts = reconstruction_error[:, 4]
reconstruction_error_imag_std = reconstruction_error[:, 5]
reconstruction_error_imag_skew = reconstruction_error[:, 6]
reconstruction_error_imag_kurtosis = reconstruction_error[:, 7]

# Plot for Real Part
plt.figure(figsize=(14, 6))
plt.plot(reconstruction_error_real_skew, label='Reconstruction Error - Real Skew', color='blue')
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error for Real Part Skew with Threshold')
plt.xlabel('Sequence Number')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('2-Reconstruction Error for Real Part with Threshold.png')
# plt.close()
plt.show()

# Plot for Imaginary Part
plt.figure(figsize=(14, 6))
plt.plot(reconstruction_error_imag_skew, label='Reconstruction Error - Imaginary Part', color='orange')
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error for Imaginary Part with Threshold')
plt.xlabel('Sequence Number')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('3-Reconstruction Error for Imaginary Part with Threshold.png')
# plt.close()
plt.show()

# %%
# Flatten the reconstruction_error to 1D
reconstruction_error_flat = reconstruction_error.flatten()
#Histogram of Reconstruction Errors:
plt.figure(figsize=(14, 6))
plt.hist(reconstruction_error_flat, bins=50, alpha=0.75)
plt.axvline(x=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Histogram of Reconstruction Errors')
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.legend()
# plt.savefig('4-Histogram of Reconstruction Errors.png')
# plt.close()
plt.show()

# %%
# real_parts, axis=1),
# np.std(real_parts, axis=1),
# skew(real_parts, axis=1),
# kurtosis(real_parts, axis=1),
# np.mean(imag_parts, axis=1),
# np.std(imag_parts, axis=1),
# skew(imag_parts, axis=1),
# kurtosis(imag_parts, axis=1)
#Time Series Plot of IQ Samples:
sample_index = np.random.choice(len(X_chunk_test))
original_sample = X_chunk_test[sample_index]
reconstructed_sample = X_chunk_pred[sample_index]

plt.figure(figsize=(16, 8))
plt.plot(original_sample[:, 0], 'b-', label='Original Real Part')
plt.plot(reconstructed_sample[:, 0], 'b--', label='Reconstructed Real Part')
plt.plot(original_sample[:, 1], 'm-', label='Original Real STD')
plt.plot(reconstructed_sample[:, 1], 'm--', label='Reconstructed Real STD')
# plt.plot(original_sample[:, 2], 'c-', label='Original Real Skew')
# plt.plot(reconstructed_sample[:, 2], 'c--', label='Reconstructed Real Skew')
# plt.plot(original_sample[:, 3], 'orange', label='Original Real Kurtosis')
# plt.plot(reconstructed_sample[:, 3], 'orange', label='Reconstructed Real Kurtosis', linestyle='--')

plt.plot(original_sample[:, 4], 'g-', label='Original Imaginary Part')
plt.plot(reconstructed_sample[:, 4], 'g--', label='Reconstructed Imaginary Part')
plt.plot(original_sample[:, 5], 'purple', label='Original Imaginary STD')
plt.plot(reconstructed_sample[:, 5], 'purple', label='Reconstructed Imaginary STD', linestyle='--')
# plt.plot(original_sample[:, 6], 'brown', label='Original Imaginary Skew')
# plt.plot(reconstructed_sample[:, 6], 'brown', label='Reconstructed Imaginary Skew', linestyle='--')
# plt.plot(original_sample[:, 7], 'pink', label='Original Imaginary Kurtosis')
# plt.plot(reconstructed_sample[:, 7], 'pink', label='Reconstructed Imaginary Kurtosis', linestyle='--')
plt.title('Original vs Reconstructed IQ Data')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')

# Place the legend outside the plot area
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize='small', title='Legend')

# Adjust layout to make room for the legend
plt.tight_layout()

plt.show()

# %%
sample_index = np.random.choice(len(X_chunk_test))
original_sample = X_chunk_test[sample_index]
reconstructed_sample = X_chunk_pred[sample_index]

plt.figure(figsize=(16, 8))
# plt.plot(original_sample[:, 0], 'b-', label='Original Real Part')
# plt.plot(reconstructed_sample[:, 0], 'b--', label='Reconstructed Real Part')
# plt.plot(original_sample[:, 1], 'm-', label='Original Real STD')
# plt.plot(reconstructed_sample[:, 1], 'm--', label='Reconstructed Real STD')
plt.plot(original_sample[:, 2], 'c-', label='Original Real Skew')
plt.plot(reconstructed_sample[:, 2], 'c--', label='Reconstructed Real Skew')
plt.plot(original_sample[:, 3], 'orange', label='Original Real Kurtosis')
plt.plot(reconstructed_sample[:, 3], 'orange', label='Reconstructed Real Kurtosis', linestyle='--')

# plt.plot(original_sample[:, 4], 'g-', label='Original Imaginary Part')
# plt.plot(reconstructed_sample[:, 4], 'g--', label='Reconstructed Imaginary Part')
# plt.plot(original_sample[:, 5], 'purple', label='Original Imaginary STD')
# plt.plot(reconstructed_sample[:, 5], 'purple', label='Reconstructed Imaginary STD', linestyle='--')
plt.plot(original_sample[:, 6], 'brown', label='Original Imaginary Skew')
plt.plot(reconstructed_sample[:, 6], 'brown', label='Reconstructed Imaginary Skew', linestyle='--')
plt.plot(original_sample[:, 7], 'pink', label='Original Imaginary Kurtosis')
plt.plot(reconstructed_sample[:, 7], 'pink', label='Reconstructed Imaginary Kurtosis', linestyle='--')
plt.title('Original vs Reconstructed IQ Data')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')

# Place the legend outside the plot area
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize='small', title='Legend')

# Adjust layout to make room for the legend
plt.tight_layout()

plt.show()

# %%
# # Define the number of sequences to plot together
n = 2  # Change this to desired number of sequences
sample_length = sequence_length * n

# Select a random starting sequence for plotting
sequence_index = np.random.choice(len(X_chunk_test) - n + 1)

# Extract and concatenate the original and reconstructed samples
original_sample = np.concatenate(X_chunk_test[sequence_index:sequence_index + n])
reconstructed_sample = np.concatenate(X_chunk_pred[sequence_index:sequence_index + n])

# Plot concatenated sequences
plt.figure(figsize=(14, 6))
plt.plot(original_sample[:, 0], 'b-', label='Original Real Part')
plt.plot(reconstructed_sample[:, 0], 'r--', label='Reconstructed Real Part')
plt.plot(original_sample[:, 1], 'orange', label='Original Real STD')
plt.plot(reconstructed_sample[:, 1], 'orange', label='Reconstructed Real STD', linestyle='--')

plt.plot(original_sample[:, 4], 'y-', label='Original Imaginary Part')
plt.plot(reconstructed_sample[:, 4], 'g--', label='Reconstructed Imaginary Part')
plt.plot(original_sample[:, 5], 'pink', label='Original Imaginary STD')
plt.plot(reconstructed_sample[:, 5], 'pink', label='Reconstructed Imaginary STD', linestyle='--')
plt.title(f'Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()
# plt.savefig('9-Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}.png')
# plt.close()
plt.show()

# %%
# Repeat for n = 9
n = 8  # Change this to desired number of sequences
sequence_index = np.random.choice(len(X_chunk_test) - n + 1)
original_sample = np.concatenate(X_chunk_test[sequence_index:sequence_index + n])
reconstructed_sample = np.concatenate(X_chunk_pred[sequence_index:sequence_index + n])

plt.figure(figsize=(14, 6))
plt.plot(original_sample[:, 2], 'b-', label='Original Real Part Skew')
plt.plot(reconstructed_sample[:, 2], 'r--', label='Reconstructed Real Part Skew')
plt.plot(original_sample[:, 6], 'g-', label='Original Imaginary Part Skew')
plt.plot(reconstructed_sample[:, 6], 'y--', label='Reconstructed Imaginary Part Skew')
plt.title(f'Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()
# plt.savefig('11-Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}.png')
# plt.close()
plt.show()

# %%
# Repeat for n = 9
n = 8  # Change this to desired number of sequences
sequence_index = np.random.choice(len(X_chunk_test) - n + 1)
original_sample = np.concatenate(X_chunk_test[sequence_index:sequence_index + n])
reconstructed_sample = np.concatenate(X_chunk_pred[sequence_index:sequence_index + n])

plt.figure(figsize=(14, 6))
plt.plot(original_sample[:, 3], 'b-', label='Original Real Part Kurtosis')
plt.plot(reconstructed_sample[:, 3], 'r--', label='Reconstructed Real Part Kurtosis')
plt.plot(original_sample[:, 7], 'g-', label='Original Imaginary Part Kurtosis')
plt.plot(reconstructed_sample[:, 7], 'y--', label='Reconstructed Imaginary Part Kurtosis')
plt.title(f'Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()
# plt.savefig('11-Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}.png')
# plt.close()
plt.show()

# %%
# Plotting the time taken for each prediction
plt.plot(prediction_times)
plt.xlabel('Prediction Number')
plt.ylabel('Time Taken (seconds)')
plt.title('Time Taken for Each Prediction')
plt.show()

# %%
# Calculate cumulative average and minimum for each prediction step
cumulative_average = np.cumsum(prediction_times) / np.arange(1, len(prediction_times) + 1)
cumulative_minimum = np.minimum.accumulate(prediction_times)


# Plot for Average Prediction Time
plt.figure(figsize=(10, 7))  # Set the figure size for better readability
plt.plot(cumulative_average, label='Cumulative Average Time')
plt.xlabel('Prediction Number')
plt.ylabel('Average Time Taken (seconds)')
plt.title('Average Prediction Time')
plt.legend()
plt.show()

# %%
# Plot for Average Prediction Time
plt.figure(figsize=(10, 7))  # Set the figure size for better readability
plt.plot(cumulative_minimum, label='Cumulative Min')
plt.xlabel('Prediction Number')
plt.ylabel('Time Taken (seconds)')
plt.title('Min Prediction Time')
plt.legend()
plt.show()

# %%
max_average_time = max(cumulative_average)

# Plot for Average Prediction Time with refined y-axis
plt.figure(figsize=(10, 7))  # Set the figure size for better readability
plt.plot(cumulative_average, label='Cumulative Average Time')
plt.xlabel('Prediction Number')
plt.ylabel('Average Time Taken (seconds)')
plt.title('Average Prediction Time')
plt.ylim(0, max_average_time)  # Set the y-axis to show from 0 to maximum average time
plt.legend()
plt.grid(True)  # Add grid for better precision viewing
plt.show()

# %%
min_average_time = min(cumulative_average)
buffer = min_average_time * 0.2  # 10% of the minimum average time for buffer

# Plot for Average Prediction Time with refined y-axis around minimum
plt.figure(figsize=(10, 7))  # Set the figure size for better readability
plt.plot(cumulative_average, label='Cumulative Average Time')
plt.xlabel('Prediction Number')
plt.ylabel('Average Time Taken (seconds)')
plt.title('Average Prediction Time')
plt.ylim(min_average_time - buffer, min_average_time + buffer)  # Zoom in on the min average time
plt.legend()
plt.grid(True)  # Add grid for better precision viewing
plt.show()
